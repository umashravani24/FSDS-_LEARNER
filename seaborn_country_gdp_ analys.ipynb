# %%
import matplotlib.pyplot as plt # visualization
import seaborn as sns # stats visualization ,advanced visualization
import pandas as pd
#% matplotlib  inline #plot the graph in the line
plt.rcParams['figure.figsize'] = (6,2) #width=6,height=2

import warnings
warnings.filterwarnings('ignore') # whenver os will update.ignore the os error

# %%
df= pd.read_csv(r"C:\Users\sss\Downloads\9th,10th - Pandas\data.csv")
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1= sns.displot(df['InternetUsers'])
vis1

# %%
vis2= sns.distplot(df['InternetUsers'])
vis2
# Out:
# <Axes: xlabel='InternetUsers', ylabel='Density'>

# %%
vis3= sns.displot(df['InternetUsers'],bins=15)
plt.rcParams['figure.figsize'] = (6,3) #width=6,height=2

# %%
vis4=sns.boxplot(data=df,x='IncomeGroup',y='BirthRate')

# %%
vis5 = sns.lmplot(data=df,x='IncomeGroup',y='BirthRate')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 vis5 = sns.lmplot(data=df,x='IncomeGroup',y='BirthRate')
#
# File c:\Users\sss\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\regression.py:640, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     637     ax.update_datalim(xys, updatey=False)
#     638     ax.autoscale_view(scaley=False)
# --> 640 facets.map_dataframe(update_datalim, x=x, y=y)
#     642 # Draw the regression plot on each facet
#     643 regplot_kws = dict(
#     644     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
# ...

# %%
vis6 = sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False,hue='IncomeGroup')

# %%
vis6 = sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=True,hue='IncomeGroup')
